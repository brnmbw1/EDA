# %% [markdown]
# <p style="color:dodgerblue; font-size: 31px; text-align:center;">
#     <b>Getting Data</b>
# </p>

# %% [markdown]
# <p style="color:black; font-size:25px;"><b>Plan:</b></p>

# %% [markdown]
# <p>
# 1. Scraping info from <a href="https://www.seedtable.com/european-startup-rankings">European startups ranking</a>.
# </p>
# <p>
#  2. Scraping info from <a href= 'https://www.crunchbase.com/'>Crunchbase</a>.
# </p>
# <p>
#  3. Storing data in a database.
# </p>

# %%
#libraries
import pandas as pd

import time  #to set a random waiting time between requests 
import random 

import requests #to make requests
from bs4 import BeautifulSoup #to parse html response from request

# %% [markdown]
# <p style="color:DodgerBlue; font-size:23px;"><b> 1. European startups ranking </b></p>

# %% [markdown]
# <p>In this part we are going to take only startups from 7 popular countries in Europe:
#
# <i><b>Germany, France, UK, Netherlands, Spain, Italy, and Switzerland</b></i>
# </p>

# %% [markdown]
# The data we are going to scrap about startups will be the following:

# %% [markdown]
# | Startup | Country | City | Description | Url |
# |------|------|------|------|------|

# %% [markdown]
# <p>
#     Where:
#
# <b><i>Startup</i></b> - <i>startup name<i/> <br>
# <b>Country</b> - <i>country where the startup was founded<i/> <br>
# <b>City</b> - <i>city of the startup <i/> <br>
# <b>Description</b> - <i>short description of the startup <i/> <br>
# <b>Url</b> - <i>url of the startup<i/> <br>

# %%
list_of_countries = ['startups-germany',
                     'startups-france',
                     'startups-uk',
                     'startups-the-netherlands',
                     'startups-spain',
                     'startups-italy',
                     'startups-switzerland'
                    ]

d = {'Startup': [],
     'Country': [],
     'City': [],
     'Description': [],
     'Url': []
    }

# %%
def seedtable_scrap(list_of_countries):
    """Scraps data about top European startups given their countries"""
        
    url = 'https://www.seedtable.com/'
    
    for country in list_of_countries:
        
        r = requests.get(url + country)
    
        soup = BeautifulSoup(r.content)
        data = soup.find_all(id="company-horizontal-card")

        c = country.split('-')[-1].capitalize()

        for i in range(1, len(data) - 1):

            d['Country'].append(c)
            d['Startup'].append(data[i].a.text)
            d['City'].append(data[i].span.text.strip())
            d['Description'].append(data[i].p.text.strip())
            d['Url'].append(data[i].a.get('href'))

# %%
seedtable_scrap(list_of_countries)

# %%
startups_table = pd.DataFrame(d)

# %%
startups_table.head(5)
# Out:
#          Startup  Country    City  \
# 0  Delivery Hero  Germany  Berlin
# 1            N26  Germany  Berlin
# 2   GetYourGuide  Germany  Berlin
# 3       Wirecard  Germany  Munich
# 4       CoachHub  Germany  Berlin
#
#                                          Description  \
# 0  Delivery Hero is a network of online food orde...
# 1  N26 offers mobile banking solutions to custome...
# 2  GetYourGuide operates an online platform for b...
# 3  Wirecard is fastest-growing digital platforms ...
# 4  CoachHub is the digital coaching provider that...
#
#                          Url
# 0   https://deliveryhero.com
# 1            https://n26.com
# 2  https://getyourguide.com/
# 3      https://wirecard.com/
# 4       https://coachhub.io/

# %% [markdown]
# <p style="color:DodgerBlue; font-size:23px;"><b> 2. Crunchbase </b></p>

# %% [markdown]
# <p>
#     In order to get additional information about startups we are going to use<i>
#     <a href="https://www.crunchbase.com/">Crunchbase</a>
#        (It is a platform for finding business information about private and public companies.) </i>

# %% [markdown]
# The data we are going to scrap about startups will be the following:

# %% [markdown]
# |Startup|Size|CB rank|Total funding|Last funding type|Investments|Acquisitions|Team members|Founded date|IPO status|Operating status|Company type|
# |------|------|------|------|------|------|------|------|------|------|------|------|

# %% [markdown]
# <p>
#     Where:
#
# <b>Startup</b> - <i>startup name</i> <br>
# <b>Size</b> - <i>number of people working in a company</i> <br>
# <b>CB rank</b> - <i>rank of a company given by crunchbase</i> <br>
# <b>Total funding</b> - <i>total amount of money company raised</i> <br>
# <b>Last funding type</b> - <i>last funding type of a company</i> <br>
# <b>Investments</b> - <i>number of investments made in other companies</i> <br>
# <b>Acquisitions</b> - <i>number of companies acquired</i> <br>
# <b>Team members</b> - <i>number of team members in crunchbase</i> <br>
# <b>Founded date</b> - <i>date the company founded</i> <br>
# <b>IPO status</b> - <i>"Private" or "Public"</i> <br>
# <b>Operating status</b> - <i>"Active" or "Closed"</i> <br>
# <b>Company type</b> - <i>"For profit" or "Non-profit"</i> <br>
# <br><br>
#     We are going to scrap additional data about industries that startup covers and put it into other dataframe to avoid repetition of startups in the main dataframe.<br> <i>(Because some startups can cover up to 10 industries, which will hugely increase the dataset)</i>

# %%
#define dictionary where will add the data
d_ = {'Startup': [],
     'Size': [],
     'CB rank': [],
     'Total funding': [],
     'Last funding type': [],
     'Investments': [],
     'Acquisitions': [],
     'Team members': [],
     'Founded date': [],
     'IPO status': [],
     'Operating status': [],
     'Company type': []
     }
industries = {'Startup': [],
             'Industry': []
             }

# %% [markdown]
# <p><i>
#     The information in the HTML files is stored in tags.<br> We are going to use Beautiful Soup library to quickly and easily access information in those tags.
# <br><br>
# We define several functions that will scrap differently stored data:
# </i></p>

# %%
def add_financial_info(soup):
    '''Adds company financial data (e.g. Total Funding Amount, Number of investors...)'''
    
    anv = soup.find('anchored-values') # financial data is stored in the tags named *anchored-values*
    
    if anv:
        for link in anv.find_all('a'):

            if link.span.span.text == 'Number of Acquisitions': 
                d_['Acquisitions'].append(link.find_all('span')[-1].text)

            elif link.span.span.text == 'Number of Investments':   
                d_['Investments'].append(link.find_all('span')[-1].text)

            elif link.span.span.text == 'Total Funding Amount': 
                d_['Total funding'].append(link.find_all('span')[-1].text)

            elif link.span.span.text == 'Number of Current Team Members': 
                d_['Team members'].append(link.find_all('span')[-1].text)

# %%
def add_general_info(soup):
    '''Adds general info about company (e.g. Founded Date, Operating Status, Num. of Employees...)'''
    
    li = soup.find_all('li')
    
    for _ in li:

        if _.a: #checks if _li_ tag contains _a_ tag

            if ('num_employees' in _.a.get('href')) & (len(d_['Size']) < len(d_['Startup'])):
                d_['Size'].append(_.a.text)

            elif ('last_funding_type' in _.a.get('href')) & (len(d_['Last funding type']) < len(d_['Startup'])):
                d_['Last funding type'].append(_.a.text)

            elif ('rank_org_company' in _.a.get('href')) & (len(d_['CB rank']) < len(d_['Startup'])): 
                d_['CB rank'].append(_.a.text)


        elif (_.span and _.span.span): #checks if _li_ tag contains _span_ tag
                                        # and if _span_ tag also contains one more span tag
            if _.span.span.text == 'Founded Date': d_['Founded date'].append(_.find_all('span')[-1].text)   #append(_.find(contexttype="profile").text)

            elif _.span.span.text == 'Operating Status': d_['Operating status'].append(_.find_all('span')[-1].text)  #append(_.find(contexttype="profile").text)

            elif _.span.span.text == 'Company Type': d_['Company type'].append(_.find_all('span')[-1].text)   #append(_.find(contexttype="profile").text)

    
    d_['IPO status'].append('Public' if 'IPO' in d_['Last funding type'][-1] else 'Private')

# %% [markdown]
# <p><i>
# In case there is no data about startup, we are going to add <b>Nan</b> values there.
# </i></p>

# %%
def add_nan_values():
    '''Checks dictionary and adds Nan values in places where there was no data in website'''
    
    t = len(d_['Startup'])
    
    for k,v in d_.items():
#         print(k,v)
        if len(v) < t:
            d_[k].append('')

# %%
def add_industries(soup,startup_name):
    '''Adds industries to their corresponding startups'''
    
    #the industry data is stored in tags with attribute 'mat-chip'
    for ind in soup.find_all('mat-chip'): 
        
        industries['Startup'].append(startup_name)
        industries['Industry'].append(ind.text)

# %% [markdown]
# <p><i>
#     With high number of requests we can be blocked from the website. <br>
#     <br>To avoid this we define a function that will make requests with a random time interval between each of the requests and also additional random time interval for each 9 requests we make.
#
#    This will allow us to gently proceed with scraping.
# <br> </i></p>

# %%
def get_request(url, headers = None, counter = [0]):
    '''Making requests with a random time interval between each.'''
    
    counter[0] += 1
    
    if counter[0] % 9 == 0:
        sleep_time = random.randint(120, 180) #random interval between 2-3 minutes each 9 requests
    else: 
        sleep_time = random.randint(45, 75) #random interval between 45-75 seconds with each request
    
    session = requests.Session()
    
    time.sleep(sleep_time) #make sleep
    
    r = session.get(url, headers = headers) #make request
    
    if r.ok: #check if server response is ok, else raise error
        return r
    else:
        r.raise_for_status()

# %% [markdown]
# <p><i>There are several startups in Crunchbase that have the same name. <br> <br>In order to get the data about our startup, we are going to use startups' urls as a unique identifier of the company, and search for this information in crunchbase using Google </i> </p>

# %%
def getting_address_from_google(startup_website):
    '''Searches for startup's Crunchbase profile in google given its url'''
    
    gsearch_url = 'https://www.google.com/search?q={}+crunchbase'.format(startup_website)
    
    r = requests.get(gsearch_url)  # request to google search's result page
    
    soup = BeautifulSoup(r.content,'html.parser')
    
    link = soup.find_all('div',class_ = 'kCrYT')[0].a.get('href')# for each result of Google I get 2 items.
                                                    # 1-Headline (containing hyperlink to the website)
                                                    # 2-Short description of the Result
        
# Thus as default google gives 10 results, soup.find_all('div',class_ = 'kCrYT') will give list of
# 20 items and the first one will be the Headline of first result containing the hyperlink.
    
    start = link.find('=') + 1  #cleaning the link
    end = link.find('&') 
    
    return link[start:end]  #returns link of this startup's profile on crunchbase

# %%
def parsing_data_from_crunchbase(df):
    '''Takes url of startup's Crunchbase profile and parses data from Crunchbase
    
    -------------
    df - DataFrame containing Startup name and its Url.
    -------------
    '''
    for s,u in df.loc[:,['Startup','Url']].itertuples(index = False):

        s_num = df.loc[df.loc[:,'Startup'] == s ].index[0]
        
        print('Now on startup number {} --> {}'.format(s_num,s))
        print('Number of startups left: {}\n'.format(df.index[-1] - s_num))
        
        link = getting_address_from_google(u)
    
        #header to behave as browser
        headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

        r = get_request(link, headers)

        soup = BeautifulSoup(r.content,'html.parser')

        d_['Startup'].append(s)

        add_general_info(soup)
        add_financial_info(soup)
        add_industries(soup, s)

        add_nan_values()

# %% [markdown]
# <p><b>Now let's scrap the data!</b></p>

# %%
parsing_data_from_crunchbase(startups_table)
# Out:
# Now on startup number 0 --> Delivery Hero
# Number of startups left: 846
#
# Now on startup number 1 --> N26
# Number of startups left: 845
#
# Now on startup number 2 --> GetYourGuide
# Number of startups left: 844
#
# Now on startup number 3 --> Wirecard
# Number of startups left: 843
#
# Now on startup number 4 --> CoachHub
# Number of startups left: 842
#
# Now on startup number 5 --> SoundCloud
# Number of startups left: 841
#
# Now on startup number 6 --> Ascent
# Number of startups left: 840
#
# Now on startup number 7 --> Lilium
# Number of startups left: 839
#
# Now on startup number 8 --> Mambu
# Number of startups left: 838
#
# Now on startup number 9 --> Raisin
# Number of startups left: 837
#
# Now on startup number 10 --> TIER
# Number of startups left: 836
#
# Now on startup number 11 --> Volocopter
# Number of startups left: 835
#
# Now on startup number 12 --> IDnow
# Number of startups left: 834
#
# Now on startup number 13 --> Helpling
# Number of startups left: 833
#
# Now on startup number 14 --> HelloFresh
# Number of startups left: 832
#
# Now on startup number 15 --> Evotec
# Number of startups left: 831
#
# Now on startup number 16 --> Omio
# Number of startups left: 830
#
# Now on startup number 17 --> G2 Esports
# Number of startups left: 829
#
# Now on startup number 18 --> SolarisBank
# Number of startups left: 828
#
# Now on startup number 19 --> Comtravo
# Number of startups left: 827
#
# Now on startup number 20 --> Circ
# Number of startups left: 826
#
# Now on startup number 21 --> WunderMobility
# Number of startups left: 825
#
# Now on startup number 22 --> Pitch
# Number of startups left: 824
#
# Now on startup number 22 --> Pitch
# Number of startups left: 824
#
# Now on startup number 24 --> Foodpanda
# Number of startups left: 822
#
# Now on startup number 25 --> Contentful
# Number of startups left: 821
#
# Now on startup number 26 --> Bunch
# Number of startups left: 820
#
# Now on startup number 27 --> Choco
# Number of startups left: 819
#
# Now on startup number 28 --> Signavio
# Number of startups left: 818
#
# Now on startup number 29 --> Billie
# Number of startups left: 817
#
# Now on startup number 30 --> Demodesk
# Number of startups left: 816
#
# Now on startup number 31 --> Blinkist
# Number of startups left: 815
#
# Now on startup number 32 --> Tourlane
# Number of startups left: 814
#
# Now on startup number 33 --> Adjust
# Number of startups left: 813
#
# Now on startup number 34 --> uberall
# Number of startups left: 812
#
# Now on startup number 35 --> Personio
# Number of startups left: 811
#
# Now on startup number 36 --> Grover
# Number of startups left: 810
#
# Now on startup number 37 --> Babbel
# Number of startups left: 809
#
# Now on startup number 38 --> Impulse Dynamics
# Number of startups left: 808
#
# Now on startup number 39 --> Sennder
# Number of startups left: 807
#
# Now on startup number 40 --> ESL
# Number of startups left: 806
#
# Now on startup number 41 --> Zalando
# Number of startups left: 805
#
# Now on startup number 42 --> Liqid
# Number of startups left: 804
#
# Now on startup number 43 --> Wunderlist
# Number of startups left: 803
#
# Now on startup number 44 --> Penta
# Number of startups left: 802
#
# Now on startup number 45 --> Kreditech
# Number of startups left: 801
#
# Now on startup number 46 --> trivago
# Number of startups left: 800
#
# Now on startup number 47 --> Clark
# Number of startups left: 799
#
# Now on startup number 48 --> AUTO1-Group
# Number of startups left: 798
#
# Now on startup number 49 --> hundred
# Number of startups left: 797
#
# Now on startup number 50 --> CrossLend
# Number of startups left: 796
#
# Now on startup number 51 --> Searchmetrics
# Number of startups left: 795
#
# Now on startup number 52 --> ResearchGate
# Number of startups left: 794
#
# Now on startup number 53 --> Blacklane
# Number of startups left: 793
#
# Now on startup number 54 --> Taxfix
# Number of startups left: 792
#
# Now on startup number 55 --> Marley Spoon
# Number of startups left: 791
#
# Now on startup number 56 --> tado
# Number of startups left: 790
#
# Now on startup number 57 --> Quandoo
# Number of startups left: 789
#
# Now on startup number 58 --> flaschenpost
# Number of startups left: 788
#
# Now on startup number 59 --> AMBOSS
# Number of startups left: 787
#
# Now on startup number 60 --> Coya
# Number of startups left: 786
#
# Now on startup number 61 --> Zeitgold
# Number of startups left: 785
#
# Now on startup number 62 --> FRIDAY
# Number of startups left: 784
#
# Now on startup number 63 --> Moonfare
# Number of startups left: 783
#
# Now on startup number 64 --> Holidu
# Number of startups left: 782
#
# Now on startup number 65 --> inne
# Number of startups left: 781
#
# Now on startup number 66 --> Zenjob
# Number of startups left: 780
#
# Now on startup number 67 --> Clue
# Number of startups left: 779
#
# Now on startup number 68 --> omnius
# Number of startups left: 778
#
# Now on startup number 69 --> zeotap
# Number of startups left: 777
#
# Now on startup number 70 --> Foodspring
# Number of startups left: 776
#
# Now on startup number 71 --> Movinga
# Number of startups left: 775
#
# Now on startup number 72 --> Bitwala
# Number of startups left: 774
#
# Now on startup number 73 --> Neufund
# Number of startups left: 773
#
# Now on startup number 74 --> Smava
# Number of startups left: 772
#
# Now on startup number 75 --> Scoutbee
# Number of startups left: 771
#
# Now on startup number 76 --> HeyJobs
# Number of startups left: 770
#
# Now on startup number 77 --> expertlead
# Number of startups left: 769
#
# Now on startup number 78 --> NavVis
# Number of startups left: 768
#
# Now on startup number 79 --> Spotcap
# Number of startups left: 767
#
# Now on startup number 80 --> Finiata
# Number of startups left: 766
#
# Now on startup number 81 --> simplesurance
# Number of startups left: 765
#
# Now on startup number 82 --> GLOSSYBOX
# Number of startups left: 764
#
# Now on startup number 83 --> Carmudi
# Number of startups left: 763
#
# Now on startup number 84 --> Acrolinx
# Number of startups left: 762
#
# Now on startup number 85 --> Exporo
# Number of startups left: 761
#
# Now on startup number 86 --> eGym
# Number of startups left: 760
#
# Now on startup number 87 --> EyeEm
# Number of startups left: 759
#
# Now on startup number 88 --> Lingoda
# Number of startups left: 758
#
# Now on startup number 89 --> Element Insurance
# Number of startups left: 757
#
# Now on startup number 90 --> Huuuge Games
# Number of startups left: 756
#
# Now on startup number 91 --> Camunda
# Number of startups left: 755
#
# Now on startup number 92 --> Joblift
# Number of startups left: 754
#
# Now on startup number 93 --> Unu motors
# Number of startups left: 753
#
# Now on startup number 94 --> Home24
# Number of startups left: 752
#
# Now on startup number 95 --> CHRONEXT
# Number of startups left: 751
#
# Now on startup number 96 --> Westwing
# Number of startups left: 750
#
# Now on startup number 97 --> Cara Care
# Number of startups left: 749
#
# Now on startup number 98 --> Medici Living Group
# Number of startups left: 748
#
# Now on startup number 99 --> Merantix
# Number of startups left: 747
#
# Now on startup number 100 --> EMnify
# Number of startups left: 746
#
# Now on startup number 101 --> Combyne
# Number of startups left: 745
#
# Now on startup number 102 --> Quarters
# Number of startups left: 744
#
# Now on startup number 103 --> Outfittery
# Number of startups left: 743
#
# Now on startup number 104 --> Global Savings Group
# Number of startups left: 742
#
# Now on startup number 105 --> Silexica
# Number of startups left: 741
#
# Now on startup number 106 --> Vimcar
# Number of startups left: 740
#
# Now on startup number 107 --> Zizoo
# Number of startups left: 739
#
# Now on startup number 108 --> thyssenkrupp
# Number of startups left: 738
#
# Now on startup number 109 --> BuildingRadar
# Number of startups left: 737
#
# Now on startup number 110 --> Friendsurance
# Number of startups left: 736
#
# Now on startup number 111 --> Mister Spex
# Number of startups left: 735
#
# Now on startup number 112 --> Riskmethods
# Number of startups left: 734
#
# Now on startup number 113 --> Thinksurance
# Number of startups left: 733
#
# Now on startup number 114 --> Medigo
# Number of startups left: 732
#
# Now on startup number 115 --> Baze
# Number of startups left: 731
#
# Now on startup number 116 --> Fyber
# Number of startups left: 730
#
# Now on startup number 117 --> Vehiculum
# Number of startups left: 729
#
# Now on startup number 118 --> InstaFreight
# Number of startups left: 728
#
# Now on startup number 119 --> AnyDesk
# Number of startups left: 727
#
# Now on startup number 120 --> Inkitt
# Number of startups left: 726
#
# Now on startup number 121 --> BlaBlaCar
# Number of startups left: 725
#
# Now on startup number 122 --> Shadow
# Number of startups left: 724
#
# Now on startup number 123 --> Meero
# Number of startups left: 723
#
# Now on startup number 124 --> Alan
# Number of startups left: 722
#
# Now on startup number 125 --> October
# Number of startups left: 721
#
# Now on startup number 126 --> Deezer
# Number of startups left: 720
#
# Now on startup number 127 --> Aircall
# Number of startups left: 719
#
# Now on startup number 128 --> Zen
# Number of startups left: 718
#
# Now on startup number 129 --> Spendesk
# Number of startups left: 717
#
# Now on startup number 130 --> Snips
# Number of startups left: 716
#
# Now on startup number 131 --> Ogury
# Number of startups left: 715
#
# Now on startup number 132 --> Doctolib
# Number of startups left: 714
#
# Now on startup number 133 --> Luko
# Number of startups left: 713
#
# Now on startup number 134 --> Heetch
# Number of startups left: 712
#
# Now on startup number 135 --> Prophesee
# Number of startups left: 711
#
# Now on startup number 136 --> Side
# Number of startups left: 710
#
# Now on startup number 137 --> Agricool
# Number of startups left: 709
#
# Now on startup number 138 --> PayFit
# Number of startups left: 708
#
# Now on startup number 139 --> Wynd
# Number of startups left: 707
#
# Now on startup number 140 --> VestiaireCollective
# Number of startups left: 706
#
# Now on startup number 141 --> Foodvisor
# Number of startups left: 705
#
# Now on startup number 142 --> Shift-Technology
# Number of startups left: 704
#
# Now on startup number 143 --> Zenaton
# Number of startups left: 703
#
# Now on startup number 144 --> ABTasty
# Number of startups left: 702
#
# Now on startup number 145 --> Back Market
# Number of startups left: 701
#
# Now on startup number 146 --> Devialet
# Number of startups left: 700
#
# Now on startup number 147 --> ManoMano
# Number of startups left: 699
#
# Now on startup number 148 --> Sendinblue
# Number of startups left: 698
#
# Now on startup number 149 --> Younited-Credit
# Number of startups left: 697
#
# Now on startup number 150 --> Brut
# Number of startups left: 696
#
# Now on startup number 151 --> Vulog
# Number of startups left: 695
#
# Now on startup number 152 --> Mirakl
# Number of startups left: 694
#
# Now on startup number 153 --> Parrot
# Number of startups left: 693
#
# Now on startup number 154 --> Evaneos
# Number of startups left: 692
#
# Now on startup number 155 --> Ledger
# Number of startups left: 691
#
# Now on startup number 156 --> EcoVadis
# Number of startups left: 690
#
# Now on startup number 157 --> Lunchr
# Number of startups left: 689
#
# Now on startup number 158 --> Team Vitality
# Number of startups left: 688
#
# Now on startup number 159 --> Akeneo
# Number of startups left: 687
#
# Now on startup number 160 --> Cityscoot
# Number of startups left: 686
#
# Now on startup number 161 --> Storefront
# Number of startups left: 685
#
# Now on startup number 162 --> BelieveDigital
# Number of startups left: 684
#
# Now on startup number 163 --> OpenClassrooms
# Number of startups left: 683
#
# Now on startup number 164 --> Everoad
# Number of startups left: 682
#
# Now on startup number 165 --> Lydia
# Number of startups left: 681
#
# Now on startup number 166 --> Dental Monitoring
# Number of startups left: 680
#
# Now on startup number 167 --> Frichti
# Number of startups left: 679
#
# Now on startup number 168 --> Virtuo
# Number of startups left: 678
#
# Now on startup number 169 --> Happn
# Number of startups left: 677
#
# Now on startup number 170 --> LumApps
# Number of startups left: 676
#
# Now on startup number 171 --> FretLink
# Number of startups left: 675
# Now on startup number 172 --> Actility
# Number of startups left: 674
#
# Now on startup number 173 --> Kayrros
# Number of startups left: 673
#
# Now on startup number 174 --> ImCheck Therapeutics
# Number of startups left: 672
#
# Now on startup number 175 --> JobTeaser
# Number of startups left: 671
#
# Now on startup number 176 --> 360Learning
# Number of startups left: 670
#
# Now on startup number 177 --> OVH
# Number of startups left: 669
#
# Now on startup number 178 --> FINALCAD
# Number of startups left: 668
#
# Now on startup number 179 --> Sinequa
# Number of startups left: 667
#
# Now on startup number 180 --> EasyMile
# Number of startups left: 666
#
# Now on startup number 181 --> NAVYA
# Number of startups left: 665
#
# Now on startup number 182 --> Sanofi Pasteur
# Number of startups left: 664
#
# Now on startup number 183 --> Kard
# Number of startups left: 663
#
# Now on startup number 184 --> Delair
# Number of startups left: 662
#
# Now on startup number 185 --> Shine
# Number of startups left: 661
#
# Now on startup number 186 --> iziwork
# Number of startups left: 660
#
# Now on startup number 187 --> Euronews
# Number of startups left: 659
#
# Now on startup number 188 --> iAdvize
# Number of startups left: 658
#
# Now on startup number 189 --> Mailjet
# Number of startups left: 657
#
# Now on startup number 190 --> Shippeo
# Number of startups left: 656
#
# Now on startup number 191 --> Predictus
# Number of startups left: 655
#
# Now on startup number 192 --> Exotec Solutions
# Number of startups left: 654
#
# Now on startup number 193 --> Malt
# Number of startups left: 653
#
# Now on startup number 194 --> AccorHotels
# Number of startups left: 652
#
# Now on startup number 195 --> Feed
# Number of startups left: 651
#
# Now on startup number 196 --> BioSerenity
# Number of startups left: 650
#
# Now on startup number 197 --> AnotherBrain
# Number of startups left: 649
#
# Now on startup number 198 --> DNA Script
# Number of startups left: 648
#
# Now on startup number 199 --> Ornikar
# Number of startups left: 647
#
# Now on startup number 200 --> Mindsay
# Number of startups left: 646
#
# Now on startup number 201 --> CybelAngel
# Number of startups left: 645
#
# Now on startup number 202 --> Tinyclues
# Number of startups left: 644
#
# Now on startup number 203 --> Anaxago
# Number of startups left: 643
#
# Now on startup number 204 --> Linkfluence
# Number of startups left: 642
#
# Now on startup number 205 --> Alkemics
# Number of startups left: 641
#
# Now on startup number 206 --> talent.io
# Number of startups left: 640
#
# Now on startup number 207 --> CardioLogs
# Number of startups left: 639
#
# Now on startup number 208 --> Deepomatic
# Number of startups left: 638
#
# Now on startup number 209 --> AgoraPulse
# Number of startups left: 637
#
# Now on startup number 210 --> Lookiero
# Number of startups left: 636
#
# Now on startup number 211 --> Armis
# Number of startups left: 635
#
# Now on startup number 212 --> HiFiBiO
# Number of startups left: 634
#
# Now on startup number 213 --> ENTEROME
# Number of startups left: 633
#
# Now on startup number 214 --> Slite
# Number of startups left: 632
#
# Now on startup number 215 --> Alsid
# Number of startups left: 631
#
# Now on startup number 216 --> Libeo
# Number of startups left: 630
#
# Now on startup number 217 --> Proprioo
# Number of startups left: 629
#
# Now on startup number 218 --> Vesper
# Number of startups left: 628
#
# Now on startup number 219 --> Luckey
# Number of startups left: 627
#
# Now on startup number 220 --> Heuritech
# Number of startups left: 626
#
# Now on startup number 221 --> Mention
# Number of startups left: 625
#
# Now on startup number 222 --> Augment
# Number of startups left: 624
#
# Now on startup number 223 --> Acticor-Biotech
# Number of startups left: 623
#
# Now on startup number 224 --> Lifen
# Number of startups left: 622
#
# Now on startup number 225 --> Herow
# Number of startups left: 621
#
# Now on startup number 226 --> Hivebrite
# Number of startups left: 620
#
# Now on startup number 227 --> Traxens
# Number of startups left: 619
#
# Now on startup number 228 --> Eligo Bioscience
# Number of startups left: 618
#
# Now on startup number 229 --> HR Path
# Number of startups left: 617
#
# Now on startup number 230 --> TravelCar
# Number of startups left: 616
#
# Now on startup number 231 --> InnovaFeed
# Number of startups left: 615
#
# Now on startup number 232 --> Poxel
# Number of startups left: 614
#
# Now on startup number 233 --> Splio
# Number of startups left: 613
#
# Now on startup number 234 --> PHENIX
# Number of startups left: 612
#
# Now on startup number 235 --> Papernest
# Number of startups left: 611
#
# Now on startup number 236 --> QWANT
# Number of startups left: 610
#
# Now on startup number 237 --> Teemo
# Number of startups left: 609
#
# Now on startup number 238 --> mojo diagnostics
# Number of startups left: 608
#
# Now on startup number 239 --> Compte Nickel
# Number of startups left: 607
#
# Now on startup number 240 --> TrustInSoft
# Number of startups left: 606
#
# Now on startup number 241 --> Baobab
# Number of startups left: 605
#
# Now on startup number 242 --> Curve
# Number of startups left: 604
#
# Now on startup number 243 --> Rapyd
# Number of startups left: 603
#
# Now on startup number 244 --> Monzo
# Number of startups left: 602
#
# Now on startup number 245 --> TransferWise
# Number of startups left: 601
#
# Now on startup number 246 --> eToro
# Number of startups left: 600
#
# Now on startup number 247 --> The Hut Group
# Number of startups left: 599
#
# Now on startup number 248 --> Funding Circle
# Number of startups left: 598
#
# Now on startup number 249 --> Cazoo
# Number of startups left: 597
#
# Now on startup number 250 --> GoCardless
# Number of startups left: 596
#
# Now on startup number 251 --> Babylon Health
# Number of startups left: 595
#
# Now on startup number 252 --> Seedrs
# Number of startups left: 594
#
# Now on startup number 253 --> IHS Markit
# Number of startups left: 593
#
# Now on startup number 254 --> Onfido
# Number of startups left: 592
#
# Now on startup number 255 --> CloudFactory
# Number of startups left: 591
#
# Now on startup number 256 --> Farfetch
# Number of startups left: 590
#
# Now on startup number 257 --> TradingView
# Number of startups left: 589
#
# Now on startup number 258 --> Medopad
# Number of startups left: 588
#
# Now on startup number 259 --> Ebury
# Number of startups left: 587
#
# Now on startup number 260 --> OakNorth
# Number of startups left: 586
#
# Now on startup number 261 --> WorldRemit
# Number of startups left: 585
#
# Now on startup number 262 --> Patch
# Number of startups left: 584
#
# Now on startup number 263 --> Spectral Edge
# Number of startups left: 583
#
# Now on startup number 264 --> OneWeb
# Number of startups left: 582
#
# Now on startup number 265 --> Immersive Labs
# Number of startups left: 581
#
# Now on startup number 266 --> Mimecast
# Number of startups left: 580
#
# Now on startup number 267 --> Greensill
# Number of startups left: 579
#
# Now on startup number 268 --> Echo
# Number of startups left: 578
#
# Now on startup number 269 --> SumUp
# Number of startups left: 577
#
# Now on startup number 270 --> Darktrace
# Number of startups left: 576
#
# Now on startup number 271 --> Improbable
# Number of startups left: 575
#
# Now on startup number 272 --> Secret Escapes
# Number of startups left: 574
#
# Now on startup number 273 --> Cleo
# Number of startups left: 573
#
# Now on startup number 274 --> Tide
# Number of startups left: 572
#
# Now on startup number 275 --> Signal AI
# Number of startups left: 571
#
# Now on startup number 276 --> LendInvest
# Number of startups left: 570
#
# Now on startup number 277 --> Citymapper
# Number of startups left: 569
#
# Now on startup number 278 --> Graphcore
# Number of startups left: 568
#
# Now on startup number 279 --> Blockchain
# Number of startups left: 567
#
# Now on startup number 280 --> Pollen
# Number of startups left: 566
#
# Now on startup number 281 --> Wefarm
# Number of startups left: 565
#
# Now on startup number 282 --> TrueLayer
# Number of startups left: 564
#
# Now on startup number 283 --> Healx
# Number of startups left: 563
#
# Now on startup number 284 --> Depop
# Number of startups left: 562
#
# Now on startup number 285 --> IMMO Investment Technologies
# Number of startups left: 561
#
# Now on startup number 286 --> Currencycloud
# Number of startups left: 560
#
# Now on startup number 287 --> Zego
# Number of startups left: 559
#
# Now on startup number 288 --> Sofar Sounds
# Number of startups left: 558
#
# Now on startup number 289 --> Nutmeg
# Number of startups left: 557
#
# Now on startup number 290 --> Tessian
# Number of startups left: 556
#
# Now on startup number 291 --> Soldo
# Number of startups left: 555
#
# Now on startup number 292 --> Checkout
# Number of startups left: 554
#
# Now on startup number 293 --> Abcam
# Number of startups left: 553
#
# Now on startup number 294 --> Elvie
# Number of startups left: 552
#
# Now on startup number 295 --> Blue Prism Group
# Number of startups left: 551
#
# Now on startup number 296 --> Receipt Bank
# Number of startups left: 550
#
# Now on startup number 297 --> COMPASS
# Number of startups left: 549
#
# Now on startup number 298 --> Telegram Messenger
# Number of startups left: 548
#
# Now on startup number 299 --> Deliveroo
# Number of startups left: 547
#
# Now on startup number 300 --> Inmarsat
# Number of startups left: 546
#
# Now on startup number 301 --> Chain
# Number of startups left: 545
#
# Now on startup number 302 --> Culture Trip
# Number of startups left: 544
#
# Now on startup number 303 --> Huddle
# Number of startups left: 543
#
# Now on startup number 304 --> Loop
# Number of startups left: 542
#
# Now on startup number 305 --> Festicket
# Number of startups left: 541
#
# Now on startup number 306 --> Revolut
# Number of startups left: 540
#
# Now on startup number 306 --> Revolut
# Number of startups left: 540
#
# Now on startup number 308 --> FaceIT
# Number of startups left: 538
#
# Now on startup number 309 --> Perkbox
# Number of startups left: 537
#
# Now on startup number 310 --> Gousto
# Number of startups left: 536
#
# Now on startup number 311 --> TransferGo
# Number of startups left: 535
#
# Now on startup number 312 --> Lightsource Renewable Energy
# Number of startups left: 534
#
# Now on startup number 313 --> OVO Energy
# Number of startups left: 533
#
# Now on startup number 314 --> Habito
# Number of startups left: 532
# Now on startup number 315 --> Carwow
# Number of startups left: 531
#
# Now on startup number 316 --> Thought Machine
# Number of startups left: 530
#
# Now on startup number 317 --> Yoyo Wallet
# Number of startups left: 529
#
# Now on startup number 318 --> MADE
# Number of startups left: 528
#
# Now on startup number 319 --> iwoca
# Number of startups left: 527
#
# Now on startup number 320 --> Chip Financial
# Number of startups left: 526
#
# Now on startup number 321 --> ComplyAdvantage
# Number of startups left: 525
#
# Now on startup number 322 --> Ring
# Number of startups left: 524
#
# Now on startup number 323 --> Access Alto
# Number of startups left: 523
#
# Now on startup number 324 --> Blippar
# Number of startups left: 522
#
# Now on startup number 325 --> Brandwatch
# Number of startups left: 521
#
# Now on startup number 326 --> Bulb
# Number of startups left: 520
#
# Now on startup number 327 --> Trussle
# Number of startups left: 519
#
# Now on startup number 328 --> Tractable
# Number of startups left: 518
#
# Now on startup number 329 --> Everledger
# Number of startups left: 517
#
# Now on startup number 330 --> Moneyfarm
# Number of startups left: 516
#
# Now on startup number 331 --> MarketInvoice
# Number of startups left: 515
#
# Now on startup number 332 --> LabGenius
# Number of startups left: 514
#
# Now on startup number 333 --> ClauseMatch
# Number of startups left: 513
#
# Now on startup number 334 --> SyndicateRoom
# Number of startups left: 512
#
# Now on startup number 335 --> IP Group Plc
# Number of startups left: 511
#
# Now on startup number 336 --> Cocoon
# Number of startups left: 510
#
# Now on startup number 337 --> PROWLER.io
# Number of startups left: 509
#
# Now on startup number 338 --> Glassbox
# Number of startups left: 508
#
# Now on startup number 339 --> ClearBank
# Number of startups left: 507
#
# Now on startup number 340 --> FiveAI
# Number of startups left: 506
#
# Now on startup number 341 --> Cervest
# Number of startups left: 505
#
# Now on startup number 342 --> Bitstamp
# Number of startups left: 504
#
# Now on startup number 343 --> Immotion Group
# Number of startups left: 503
#
# Now on startup number 344 --> SenSat
# Number of startups left: 502
#
# Now on startup number 345 --> Augmentum Fintech
# Number of startups left: 501
#
# Now on startup number 346 --> Divido
# Number of startups left: 500
#
# Now on startup number 347 --> FundamentalVR
# Number of startups left: 499
#
# Now on startup number 348 --> Featurespace
# Number of startups left: 498
#
# Now on startup number 349 --> Keyless
# Number of startups left: 497
#
# Now on startup number 350 --> Moneybox
# Number of startups left: 496
#
# Now on startup number 351 --> BluJay Solutions
# Number of startups left: 495
#
# Now on startup number 352 --> Kheiron
# Number of startups left: 494
#
# Now on startup number 353 --> Push Doctor
# Number of startups left: 493
#
# Now on startup number 354 --> Disperse
# Number of startups left: 492
#
# Now on startup number 355 --> Brightpearl
# Number of startups left: 491
#
# Now on startup number 356 --> Starling Bank
# Number of startups left: 490
#
# Now on startup number 357 --> Impala
# Number of startups left: 489
#
# Now on startup number 358 --> Getronics
# Number of startups left: 488
#
# Now on startup number 359 --> Bottle Pay
# Number of startups left: 487
#
# Now on startup number 360 --> Hummingbird Technologies
# Number of startups left: 486
#
# Now on startup number 361 --> Peak
# Number of startups left: 485
#
# Now on startup number 362 --> XR Games
# Number of startups left: 484
#
# Now on startup number 363 --> MessageBird
# Number of startups left: 483
#
# Now on startup number 364 --> Picnic
# Number of startups left: 482
#
# Now on startup number 365 --> Tiqets
# Number of startups left: 481
#
# Now on startup number 366 --> Bitfury
# Number of startups left: 480
#
# Now on startup number 367 --> bunq
# Number of startups left: 479
#
# Now on startup number 368 --> ROBIN
# Number of startups left: 478
#
# Now on startup number 369 --> Fastned
# Number of startups left: 477
#
# Now on startup number 370 --> Etergo
# Number of startups left: 476
#
# Now on startup number 371 --> Takeaway
# Number of startups left: 475
#
# Now on startup number 372 --> dott
# Number of startups left: 474
#
# Now on startup number 373 --> Sketch
# Number of startups left: 473
#
# Now on startup number 374 --> BUX
# Number of startups left: 472
#
# Now on startup number 375 --> Fairphone
# Number of startups left: 471
#
# Now on startup number 376 --> Framer
# Number of startups left: 470
#
# Now on startup number 377 --> WeTransfer
# Number of startups left: 469
#
# Now on startup number 378 --> Bynder
# Number of startups left: 468
#
# Now on startup number 379 --> Bidroom
# Number of startups left: 467
#
# Now on startup number 380 --> 3D Hubs
# Number of startups left: 466
#
# Now on startup number 381 --> VANMOOF
# Number of startups left: 465
#
# Now on startup number 382 --> Catawiki
# Number of startups left: 464
#
# Now on startup number 383 --> EclecticIQ
# Number of startups left: 463
#
# Now on startup number 384 --> Adyen
# Number of startups left: 462
#
# Now on startup number 385 --> Medal
# Number of startups left: 461
#
# Now on startup number 386 --> Office App
# Number of startups left: 460
#
# Now on startup number 387 --> Virtuagym
# Number of startups left: 459
#
# Now on startup number 388 --> Pyramid Analytics
# Number of startups left: 458
#
# Now on startup number 389 --> Hiber
# Number of startups left: 457
#
# Now on startup number 390 --> SkinVision
# Number of startups left: 456
#
# Now on startup number 391 --> Crisp
# Number of startups left: 455
#
# Now on startup number 392 --> Polarsteps
# Number of startups left: 454
#
# Now on startup number 393 --> ZIVVER
# Number of startups left: 453
#
# Now on startup number 394 --> arGEN-X
# Number of startups left: 452
#
# Now on startup number 395 --> Aidence
# Number of startups left: 451
#
# Now on startup number 396 --> Surfly
# Number of startups left: 450
#
# Now on startup number 397 --> Otrium
# Number of startups left: 449
#
# Now on startup number 398 --> Agendia
# Number of startups left: 448
#
# Now on startup number 399 --> Nova Lumos
# Number of startups left: 447
#
# Now on startup number 400 --> NN Group
# Number of startups left: 446
#
# Now on startup number 401 --> CarePay
# Number of startups left: 445
#
# Now on startup number 402 --> Connecterra
# Number of startups left: 444
#
# Now on startup number 403 --> Peerby
# Number of startups left: 443
#
# Now on startup number 404 --> Ohpen
# Number of startups left: 442
#
# Now on startup number 405 --> EVBox
# Number of startups left: 441
#
# Now on startup number 406 --> inSided
# Number of startups left: 440
#
# Now on startup number 407 --> Digital Insurance Group
# Number of startups left: 439
#
# Now on startup number 408 --> Siilo
# Number of startups left: 438
#
# Now on startup number 409 --> CodeSandbox
# Number of startups left: 437
#
# Now on startup number 410 --> OneFit
# Number of startups left: 436
#
# Now on startup number 411 --> Deeptrace
# Number of startups left: 435
#
# Now on startup number 412 --> Sensara
# Number of startups left: 434
#
# Now on startup number 413 --> Kambr
# Number of startups left: 433
#
# Now on startup number 414 --> myTomorrows
# Number of startups left: 432
#
# Now on startup number 415 --> Usabilla
# Number of startups left: 431
#
# Now on startup number 416 --> Shleep
# Number of startups left: 430
#
# Now on startup number 417 --> Lieferando
# Number of startups left: 429
#
# Now on startup number 418 --> ViriCiti
# Number of startups left: 428
#
# Now on startup number 419 --> O3b Networks
# Number of startups left: 427
#
# Now on startup number 420 --> Bundle
# Number of startups left: 426
#
# Now on startup number 421 --> Quicargo
# Number of startups left: 425
#
# Now on startup number 422 --> Cleeng
# Number of startups left: 424
#
# Now on startup number 423 --> felyx
# Number of startups left: 423
#
# Now on startup number 424 --> Lift
# Number of startups left: 422
#
# Now on startup number 425 --> FlexClub
# Number of startups left: 421
#
# Now on startup number 426 --> ParkBee
# Number of startups left: 420
#
# Now on startup number 427 --> DEGIRO
# Number of startups left: 419
#
# Now on startup number 428 --> Avantium Technologies
# Number of startups left: 418
#
# Now on startup number 429 --> FiveDegrees
# Number of startups left: 417
#
# Now on startup number 430 --> Owlin
# Number of startups left: 416
#
# Now on startup number 431 --> Triposo
# Number of startups left: 415
#
# Now on startup number 432 --> TerraPay
# Number of startups left: 414
#
# Now on startup number 433 --> Roamler
# Number of startups left: 413
#
# Now on startup number 434 --> Aito
# Number of startups left: 412
#
# Now on startup number 435 --> Taxi2airport
# Number of startups left: 411
#
# Now on startup number 436 --> AdviceRobo
# Number of startups left: 410
#
# Now on startup number 437 --> Hatch
# Number of startups left: 409
#
# Now on startup number 438 --> Hotelchamp
# Number of startups left: 408
#
# Now on startup number 439 --> Route4Gas
# Number of startups left: 407
#
# Now on startup number 440 --> Dyme
# Number of startups left: 406
#
# Now on startup number 441 --> Whatagraph
# Number of startups left: 405
#
# Now on startup number 442 --> Helloprint
# Number of startups left: 404
#
# Now on startup number 443 --> Reynen Court
# Number of startups left: 403
#
# Now on startup number 444 --> 24sessions
# Number of startups left: 402
#
# Now on startup number 445 --> Unless
# Number of startups left: 401
#
# Now on startup number 446 --> Sensoterra
# Number of startups left: 400
#
# Now on startup number 447 --> 30MHz
# Number of startups left: 399
#
# Now on startup number 448 --> Silk
# Number of startups left: 398
#
# Now on startup number 449 --> SEGRON
# Number of startups left: 397
#
# Now on startup number 450 --> Vamp
# Number of startups left: 396
#
# Now on startup number 451 --> Land Life Company
# Number of startups left: 395
#
# Now on startup number 452 --> SwipeGuide
# Number of startups left: 394
#
# Now on startup number 453 --> AliveShoes
# Number of startups left: 393
#
# Now on startup number 454 --> Starred
# Number of startups left: 392
#
# Now on startup number 455 --> MP Objects
# Number of startups left: 391
# Now on startup number 456 --> Gameye
# Number of startups left: 390
#
# Now on startup number 457 --> Wonderkind
# Number of startups left: 389
#
# Now on startup number 458 --> Tradefox
# Number of startups left: 388
#
# Now on startup number 459 --> Lendahand
# Number of startups left: 387
#
# Now on startup number 460 --> Lone Rooftop
# Number of startups left: 386
#
# Now on startup number 461 --> CoolGames
# Number of startups left: 385
#
# Now on startup number 462 --> Wercker
# Number of startups left: 384
#
# Now on startup number 463 --> Deskbookers
# Number of startups left: 383
#
# Now on startup number 464 --> Airchip
# Number of startups left: 382
#
# Now on startup number 465 --> Cybersprint
# Number of startups left: 381
#
# Now on startup number 466 --> SemioticLabs
# Number of startups left: 380
#
# Now on startup number 467 --> Tykn
# Number of startups left: 379
#
# Now on startup number 468 --> EcoChain Technologies
# Number of startups left: 378
#
# Now on startup number 469 --> Talmundo
# Number of startups left: 377
#
# Now on startup number 470 --> Travis the Translator
# Number of startups left: 376
#
# Now on startup number 471 --> Braingineers
# Number of startups left: 375
#
# Now on startup number 472 --> TRVL
# Number of startups left: 374
#
# Now on startup number 473 --> BuyBay
# Number of startups left: 373
#
# Now on startup number 474 --> PastBook
# Number of startups left: 372
#
# Now on startup number 475 --> Iristrace
# Number of startups left: 371
#
# Now on startup number 476 --> Camptoo
# Number of startups left: 370
#
# Now on startup number 477 --> Mazarine Energy
# Number of startups left: 369
#
# Now on startup number 478 --> InvoiceSharing
# Number of startups left: 368
#
# Now on startup number 479 --> Airborne
# Number of startups left: 367
#
# Now on startup number 480 --> Vakanties.nl
# Number of startups left: 366
#
# Now on startup number 481 --> Finturi
# Number of startups left: 365
#
# Now on startup number 482 --> CX Company
# Number of startups left: 364
#
# Now on startup number 483 --> RedSocks Security
# Number of startups left: 363
#
# Now on startup number 484 --> Badi
# Number of startups left: 362
#
# Now on startup number 485 --> Spotahome
# Number of startups left: 361
#
# Now on startup number 486 --> TravelPerk
# Number of startups left: 360
#
# Now on startup number 487 --> Marfeel
# Number of startups left: 359
#
# Now on startup number 488 --> Cabify
# Number of startups left: 358
#
# Now on startup number 489 --> Bnext
# Number of startups left: 357
#
# Now on startup number 490 --> Mr Jeff
# Number of startups left: 356
#
# Now on startup number 491 --> Typeform
# Number of startups left: 355
#
# Now on startup number 492 --> ID Finance
# Number of startups left: 354
#
# Now on startup number 493 --> Copado
# Number of startups left: 353
#
# Now on startup number 494 --> Worldcoo
# Number of startups left: 352
#
# Now on startup number 495 --> Wind Mobility
# Number of startups left: 351
#
# Now on startup number 496 --> Verse
# Number of startups left: 350
#
# Now on startup number 497 --> Wallapop
# Number of startups left: 349
#
# Now on startup number 498 --> fintonic
# Number of startups left: 348
#
# Now on startup number 499 --> Anaconda
# Number of startups left: 347
#
# Now on startup number 500 --> TAPP Water
# Number of startups left: 346
#
# Now on startup number 501 --> Holaluz
# Number of startups left: 345
#
# Now on startup number 502 --> Housfy
# Number of startups left: 344
#
# Now on startup number 503 --> Holded
# Number of startups left: 343
#
# Now on startup number 504 --> Neo
# Number of startups left: 342
#
# Now on startup number 505 --> Xceed
# Number of startups left: 341
#
# Now on startup number 506 --> Lingokids
# Number of startups left: 340
#
# Now on startup number 507 --> Stuart
# Number of startups left: 339
#
# Now on startup number 508 --> Bipi
# Number of startups left: 338
#
# Now on startup number 509 --> Smart Protection
# Number of startups left: 337
#
# Now on startup number 510 --> Social Point
# Number of startups left: 336
#
# Now on startup number 511 --> Noken
# Number of startups left: 335
#
# Now on startup number 512 --> CornerJob
# Number of startups left: 334
#
# Now on startup number 513 --> Pagantis
# Number of startups left: 333
#
# Now on startup number 514 --> Lodgify
# Number of startups left: 332
#
# Now on startup number 515 --> Privalia
# Number of startups left: 331
#
# Now on startup number 516 --> Psious
# Number of startups left: 330
#
# Now on startup number 517 --> Ironhack
# Number of startups left: 329
#
# Now on startup number 518 --> ForceManager
# Number of startups left: 328
#
# Now on startup number 519 --> OrbitalAds
# Number of startups left: 327
#
# Now on startup number 520 --> Colvin
# Number of startups left: 326
#
# Now on startup number 521 --> iContainers
# Number of startups left: 325
#
# Now on startup number 522 --> buguroo
# Number of startups left: 324
#
# Now on startup number 523 --> BYHOURS
# Number of startups left: 323
#
# Now on startup number 524 --> Signaturit
# Number of startups left: 322
#
# Now on startup number 525 --> Cooltra
# Number of startups left: 321
#
# Now on startup number 526 --> Whisbi
# Number of startups left: 320
#
# Now on startup number 527 --> ValidatedID
# Number of startups left: 319
#
# Now on startup number 528 --> eCooltra
# Number of startups left: 318
#
# Now on startup number 529 --> Worldsensing
# Number of startups left: 317
#
# Now on startup number 530 --> Citibox
# Number of startups left: 316
#
# Now on startup number 531 --> Mediktor
# Number of startups left: 315
#
# Now on startup number 532 --> Woffu
# Number of startups left: 314
#
# Now on startup number 533 --> Source{d}
# Number of startups left: 313
#
# Now on startup number 534 --> MrNoow
# Number of startups left: 312
#
# Now on startup number 535 --> Packlink
# Number of startups left: 311
#
# Now on startup number 536 --> Blueliv
# Number of startups left: 310
#
# Now on startup number 537 --> Fon
# Number of startups left: 309
#
# Now on startup number 538 --> Oryzon Genomics
# Number of startups left: 308
#
# Now on startup number 539 --> Startupxplore
# Number of startups left: 307
#
# Now on startup number 540 --> NoviCap
# Number of startups left: 306
#
# Now on startup number 541 --> Goin
# Number of startups left: 305
#
# Now on startup number 542 --> Coverfy
# Number of startups left: 304
#
# Now on startup number 543 --> ProntoPiso
# Number of startups left: 303
#
# Now on startup number 544 --> Capital Cell
# Number of startups left: 302
#
# Now on startup number 545 --> Fundsfy
# Number of startups left: 301
#
# Now on startup number 546 --> Top Doctors
# Number of startups left: 300
#
# Now on startup number 547 --> YEGO
# Number of startups left: 299
#
# Now on startup number 548 --> ABA English
# Number of startups left: 298
#
# Now on startup number 549 --> bdeo
# Number of startups left: 297
#
# Now on startup number 550 --> Housers
# Number of startups left: 296
#
# Now on startup number 551 --> PlayGiga
# Number of startups left: 295
#
# Now on startup number 552 --> WOOM
# Number of startups left: 294
#
# Now on startup number 553 --> Elma Care
# Number of startups left: 293
#
# Now on startup number 554 --> SamyRoad
# Number of startups left: 292
#
# Now on startup number 555 --> PromoFarma
# Number of startups left: 291
#
# Now on startup number 556 --> Deporvillage
# Number of startups left: 290
#
# Now on startup number 557 --> Qustodio
# Number of startups left: 289
#
# Now on startup number 558 --> BusUp
# Number of startups left: 288
#
# Now on startup number 559 --> Pangea
# Number of startups left: 287
#
# Now on startup number 560 --> Graphext
# Number of startups left: 286
#
# Now on startup number 561 --> Telxius
# Number of startups left: 285
#
# Now on startup number 562 --> Minoryx
# Number of startups left: 284
#
# Now on startup number 563 --> World-Mastery
# Number of startups left: 283
#
# Now on startup number 564 --> Billin
# Number of startups left: 282
#
# Now on startup number 565 --> Nautal
# Number of startups left: 281
#
# Now on startup number 566 --> GetApp
# Number of startups left: 280
#
# Now on startup number 567 --> MMG
# Number of startups left: 279
#
# Now on startup number 568 --> Hubtype
# Number of startups left: 278
#
# Now on startup number 569 --> STAT-Dx
# Number of startups left: 277
#
# Now on startup number 570 --> Lola Market
# Number of startups left: 276
#
# Now on startup number 571 --> Beabloo
# Number of startups left: 275
#
# Now on startup number 572 --> Unnax
# Number of startups left: 274
#
# Now on startup number 573 --> Gestoos
# Number of startups left: 273
#
# Now on startup number 574 --> ABLE Human Motion
# Number of startups left: 272
#
# Now on startup number 575 --> AERVIO
# Number of startups left: 271
#
# Now on startup number 576 --> Peoople
# Number of startups left: 270
#
# Now on startup number 577 --> Adsmurai
# Number of startups left: 269
#
# Now on startup number 578 --> Agroptima
# Number of startups left: 268
#
# Now on startup number 579 --> Iomob
# Number of startups left: 267
#
# Now on startup number 580 --> Safe365
# Number of startups left: 266
#
# Now on startup number 581 --> ReviewPro
# Number of startups left: 265
#
# Now on startup number 582 --> Spaceboost
# Number of startups left: 264
#
# Now on startup number 583 --> Tropicfeel
# Number of startups left: 263
#
# Now on startup number 584 --> Finizens
# Number of startups left: 262
#
# Now on startup number 585 --> Pulpomatic
# Number of startups left: 261
#
# Now on startup number 586 --> DEXMA
# Number of startups left: 260
#
# Now on startup number 587 --> FacePhi
# Number of startups left: 259
#
# Now on startup number 588 --> Seedtag
# Number of startups left: 258
#
# Now on startup number 589 --> Doist
# Number of startups left: 257
#
# Now on startup number 590 --> Civiciti
# Number of startups left: 256
#
# Now on startup number 591 --> Sheetgo
# Number of startups left: 255
#
# Now on startup number 592 --> LeanXcale
# Number of startups left: 254
#
# Now on startup number 593 --> Reloadly
# Number of startups left: 253
#
# Now on startup number 594 --> chicfy
# Number of startups left: 252
#
# Now on startup number 595 --> Lyntia
# Number of startups left: 251
#
# Now on startup number 596 --> MedUX
# Number of startups left: 250
#
# Now on startup number 597 --> B-wom
# Number of startups left: 249
#
# Now on startup number 598 --> OnTruck
# Number of startups left: 248
# Now on startup number 599 --> Verbio
# Number of startups left: 247
#
# Now on startup number 600 --> Aplazame
# Number of startups left: 246
#
# Now on startup number 601 --> Equidam
# Number of startups left: 245
#
# Now on startup number 602 --> beWanted
# Number of startups left: 244
#
# Now on startup number 603 --> ApetEat
# Number of startups left: 243
#
# Now on startup number 604 --> RatedPower
# Number of startups left: 242
#
# Now on startup number 44 --> Penta
# Number of startups left: 802
#
# Now on startup number 606 --> Satispay
# Number of startups left: 240
#
# Now on startup number 607 --> Supermercato24
# Number of startups left: 239
#
# Now on startup number 608 --> Delos
# Number of startups left: 238
#
# Now on startup number 609 --> Uala
# Number of startups left: 237
#
# Now on startup number 610 --> Musement
# Number of startups left: 236
#
# Now on startup number 611 --> D-Orbit
# Number of startups left: 235
#
# Now on startup number 612 --> Eligo
# Number of startups left: 234
#
# Now on startup number 613 --> Credimi
# Number of startups left: 233
#
# Now on startup number 614 --> ForTune
# Number of startups left: 232
#
# Now on startup number 615 --> Cortilia
# Number of startups left: 231
#
# Now on startup number 616 --> Together Price
# Number of startups left: 230
#
# Now on startup number 617 --> ICONIUM
# Number of startups left: 229
#
# Now on startup number 618 --> ELSE-Corp
# Number of startups left: 228
#
# Now on startup number 619 --> Sweetguest
# Number of startups left: 227
#
# Now on startup number 620 --> Mercurius
# Number of startups left: 226
#
# Now on startup number 621 --> Leaf Space
# Number of startups left: 225
#
# Now on startup number 622 --> Volvero
# Number of startups left: 224
#
# Now on startup number 623 --> Newronika
# Number of startups left: 223
#
# Now on startup number 624 --> SQUARE MM
# Number of startups left: 222
#
# Now on startup number 625 --> Young Platform
# Number of startups left: 221
#
# Now on startup number 626 --> armadioverde
# Number of startups left: 220
#
# Now on startup number 627 --> FrescoFrigo
# Number of startups left: 219
#
# Now on startup number 628 --> GoVolt
# Number of startups left: 218
#
# Now on startup number 629 --> Wanderio
# Number of startups left: 217
#
# Now on startup number 630 --> Lokky
# Number of startups left: 216
#
# Now on startup number 631 --> Linkem
# Number of startups left: 215
#
# Now on startup number 632 --> EatsReady
# Number of startups left: 214
#
# Now on startup number 633 --> Axieme
# Number of startups left: 213
#
# Now on startup number 634 --> Neosurance
# Number of startups left: 212
#
# Now on startup number 635 --> Beintoo
# Number of startups left: 211
#
# Now on startup number 636 --> Contactlab
# Number of startups left: 210
#
# Now on startup number 637 --> Assiteca
# Number of startups left: 209
#
# Now on startup number 638 --> Tutored
# Number of startups left: 208
#
# Now on startup number 639 --> MAAM
# Number of startups left: 207
#
# Now on startup number 640 --> CoreView
# Number of startups left: 206
#
# Now on startup number 641 --> Userbot
# Number of startups left: 205
#
# Now on startup number 642 --> Resonance AI
# Number of startups left: 204
#
# Now on startup number 643 --> MioAssicuratore
# Number of startups left: 203
#
# Now on startup number 644 --> Scuter
# Number of startups left: 202
#
# Now on startup number 645 --> Drexcode
# Number of startups left: 201
#
# Now on startup number 646 --> Mymenu
# Number of startups left: 200
#
# Now on startup number 647 --> Splitty Pay
# Number of startups left: 199
#
# Now on startup number 648 --> LOVEThESIGN
# Number of startups left: 198
#
# Now on startup number 649 --> CarPlanner
# Number of startups left: 197
#
# Now on startup number 650 --> Deesup
# Number of startups left: 196
#
# Now on startup number 651 --> TXC Markets
# Number of startups left: 195
#
# Now on startup number 652 --> Bandyer
# Number of startups left: 194
#
# Now on startup number 653 --> ROIALTY
# Number of startups left: 193
#
# Now on startup number 654 --> Yocabè
# Number of startups left: 192
#
# Now on startup number 655 --> Workinvoice
# Number of startups left: 191
#
# Now on startup number 656 --> Shampora
# Number of startups left: 190
#
# Now on startup number 657 --> Growish
# Number of startups left: 189
#
# Now on startup number 658 --> Moneymour
# Number of startups left: 188
#
# Now on startup number 659 --> CrowdFundMe
# Number of startups left: 187
#
# Now on startup number 660 --> Rolling Pandas
# Number of startups left: 186
#
# Now on startup number 661 --> Vikey
# Number of startups left: 185
#
# Now on startup number 662 --> BigProfiles
# Number of startups left: 184
#
# Now on startup number 663 --> Enel
# Number of startups left: 183
#
# Now on startup number 664 --> Quomi
# Number of startups left: 182
#
# Now on startup number 665 --> 24 Ore Business School
# Number of startups left: 181
#
# Now on startup number 666 --> wineOwine
# Number of startups left: 180
#
# Now on startup number 667 --> Chef in Camicia
# Number of startups left: 179
#
# Now on startup number 668 --> GenomeUp
# Number of startups left: 178
#
# Now on startup number 669 --> Beast Technologies
# Number of startups left: 177
#
# Now on startup number 670 --> Fluida Europe
# Number of startups left: 176
#
# Now on startup number 671 --> Neat
# Number of startups left: 175
#
# Now on startup number 672 --> X-next
# Number of startups left: 174
#
# Now on startup number 673 --> Pedius
# Number of startups left: 173
#
# Now on startup number 674 --> Bauzaar
# Number of startups left: 172
#
# Now on startup number 675 --> B2Book
# Number of startups left: 171
#
# Now on startup number 676 --> Deliverart
# Number of startups left: 170
#
# Now on startup number 677 --> Social Academy
# Number of startups left: 169
#
# Now on startup number 678 --> Le Cicogne
# Number of startups left: 168
#
# Now on startup number 679 --> ARTKNIT STUDIOS
# Number of startups left: 167
#
# Now on startup number 680 --> Apps-Builder
# Number of startups left: 166
#
# Now on startup number 681 --> FRUITSAPP
# Number of startups left: 165
#
# Now on startup number 682 --> Dianax
# Number of startups left: 164
#
# Now on startup number 683 --> UXGO
# Number of startups left: 163
#
# Now on startup number 684 --> Pony Zero
# Number of startups left: 162
#
# Now on startup number 685 --> nCore
# Number of startups left: 161
#
# Now on startup number 686 --> PrenotaUnCampo
# Number of startups left: 160
#
# Now on startup number 687 --> Revotree
# Number of startups left: 159
#
# Now on startup number 688 --> 200crowd
# Number of startups left: 158
#
# Now on startup number 689 --> Inkdome
# Number of startups left: 157
#
# Now on startup number 690 --> AdvisorEat
# Number of startups left: 156
#
# Now on startup number 691 --> Italy Innovazioni
# Number of startups left: 155
#
# Now on startup number 692 --> WayCap
# Number of startups left: 154
#
# Now on startup number 693 --> Direttoo
# Number of startups left: 153
#
# Now on startup number 694 --> Namu
# Number of startups left: 152
#
# Now on startup number 695 --> Yakkyo
# Number of startups left: 151
#
# Now on startup number 696 --> Fixool
# Number of startups left: 150
#
# Now on startup number 697 --> Diet-to-go
# Number of startups left: 149
#
# Now on startup number 698 --> AR Market
# Number of startups left: 148
#
# Now on startup number 699 --> RisparmioSuper
# Number of startups left: 147
#
# Now on startup number 700 --> Hibye
# Number of startups left: 146
#
# Now on startup number 701 --> Solenica
# Number of startups left: 145
#
# Now on startup number 702 --> DailyInternship
# Number of startups left: 144
#
# Now on startup number 703 --> Quokka
# Number of startups left: 143
#
# Now on startup number 704 --> MyLab Nutrition
# Number of startups left: 142
#
# Now on startup number 705 --> GreenItaly1
# Number of startups left: 141
#
# Now on startup number 706 --> Advise Only
# Number of startups left: 140
#
# Now on startup number 707 --> Sport Grand Tour
# Number of startups left: 139
#
# Now on startup number 708 --> Airgloss
# Number of startups left: 138
#
# Now on startup number 709 --> FindMyLost
# Number of startups left: 137
#
# Now on startup number 710 --> Arbitryum
# Number of startups left: 136
#
# Now on startup number 711 --> IndaBox
# Number of startups left: 135
#
# Now on startup number 712 --> Skuola
# Number of startups left: 134
#
# Now on startup number 713 --> HURBA
# Number of startups left: 133
#
# Now on startup number 714 --> Eggup
# Number of startups left: 132
#
# Now on startup number 715 --> TiAssisto24
# Number of startups left: 131
#
# Now on startup number 716 --> WeSchool
# Number of startups left: 130
#
# Now on startup number 717 --> EXTRABANCA
# Number of startups left: 129
#
# Now on startup number 718 --> eBoox
# Number of startups left: 128
#
# Now on startup number 719 --> HiRide Suspension
# Number of startups left: 127
#
# Now on startup number 720 --> Jobmetoo
# Number of startups left: 126
#
# Now on startup number 721 --> In Time Link
# Number of startups left: 125
#
# Now on startup number 722 --> Chef Dovunque
# Number of startups left: 124
#
# Now on startup number 723 --> GoalShouter
# Number of startups left: 123
#
# Now on startup number 724 --> Hi-Interiors
# Number of startups left: 122
#
# Now on startup number 725 --> Blubrake
# Number of startups left: 121
#
# Now on startup number 726 --> Daedalean
# Number of startups left: 120
#
# Now on startup number 727 --> Avaloq
# Number of startups left: 119
#
# Now on startup number 728 --> Wire
# Number of startups left: 118
#
# Now on startup number 729 --> DISCO
# Number of startups left: 117
#
# Now on startup number 730 --> Beekeeper
# Number of startups left: 116
#
# Now on startup number 731 --> responsAbility
# Number of startups left: 115
#
# Now on startup number 732 --> Luxoft
# Number of startups left: 114
#
# Now on startup number 733 --> Nexo
# Number of startups left: 113
#
# Now on startup number 734 --> Coople
# Number of startups left: 112
#
# Now on startup number 44 --> Penta
# Number of startups left: 802
#
# Now on startup number 736 --> Veeam Software
# Number of startups left: 110
#
# Now on startup number 737 --> Biovotion
# Number of startups left: 109
#
# Now on startup number 738 --> Annanow Group
# Number of startups left: 108
#
# Now on startup number 739 --> Scandit
# Number of startups left: 107
#
# Now on startup number 740 --> ProtonMail
# Number of startups left: 106
#
# Now on startup number 741 --> SOPHiA GENETICS
# Number of startups left: 105
#
# Now on startup number 742 --> Ava
# Number of startups left: 104
#
# Now on startup number 743 --> WayRay
# Number of startups left: 103
#
# Now on startup number 744 --> Cellestia Biotech
# Number of startups left: 102
#
# Now on startup number 745 --> Aleva Neurotherapeutics
# Number of startups left: 101
#
# Now on startup number 746 --> Sportradar
# Number of startups left: 100
#
# Now on startup number 747 --> MindMaze
# Number of startups left: 99
#
# Now on startup number 748 --> Numbrs
# Number of startups left: 98
#
# Now on startup number 749 --> Avrios
# Number of startups left: 97
#
# Now on startup number 750 --> ONEDAY
# Number of startups left: 96
#
# Now on startup number 751 --> Nexxiot
# Number of startups left: 95
#
# Now on startup number 752 --> Teralytics
# Number of startups left: 94
#
# Now on startup number 753 --> Planted Foods
# Number of startups left: 93
#
# Now on startup number 754 --> Bancor
# Number of startups left: 92
#
# Now on startup number 755 --> ABB
# Number of startups left: 91
#
# Now on startup number 756 --> UrbanAlps
# Number of startups left: 90
#
# Now on startup number 757 --> Frontify
# Number of startups left: 89
#
# Now on startup number 758 --> Flyability
# Number of startups left: 88
#
# Now on startup number 759 --> KNIME
# Number of startups left: 87
#
# Now on startup number 760 --> MoonX
# Number of startups left: 86
#
# Now on startup number 761 --> ICON
# Number of startups left: 85
#
# Now on startup number 762 --> SonarSource
# Number of startups left: 84
#
# Now on startup number 763 --> Tresorit
# Number of startups left: 83
#
# Now on startup number 764 --> Status.im
# Number of startups left: 82
#
# Now on startup number 765 --> Utrust
# Number of startups left: 81
#
# Now on startup number 766 --> Squirro
# Number of startups left: 80
#
# Now on startup number 767 --> N-Dream
# Number of startups left: 79
#
# Now on startup number 768 --> ROVENSO
# Number of startups left: 78
#
# Now on startup number 769 --> RoomPriceGenie
# Number of startups left: 77
#
# Now on startup number 770 --> Kandou Bus
# Number of startups left: 76
#
# Now on startup number 771 --> ProcSea
# Number of startups left: 75
#
# Now on startup number 772 --> Masha.ai
# Number of startups left: 74
# Now on startup number 773 --> Hosco
# Number of startups left: 73
#
# Now on startup number 774 --> RetinAI Medical
# Number of startups left: 72
#
# Now on startup number 775 --> Cosmos Network
# Number of startups left: 71
#
# Now on startup number 776 --> B3i
# Number of startups left: 70
#
# Now on startup number 777 --> Crypto Finance
# Number of startups left: 69
#
# Now on startup number 778 --> Akselos
# Number of startups left: 68
#
# Now on startup number 779 --> Advanon
# Number of startups left: 67
#
# Now on startup number 780 --> GenomSys
# Number of startups left: 66
#
# Now on startup number 781 --> MaxiVAX
# Number of startups left: 65
#
# Now on startup number 782 --> Verity Studios
# Number of startups left: 64
#
# Now on startup number 783 --> Ambrosus
# Number of startups left: 63
#
# Now on startup number 784 --> SMART VALOR
# Number of startups left: 62
#
# Now on startup number 785 --> Hydromea
# Number of startups left: 61
#
# Now on startup number 786 --> Knip
# Number of startups left: 60
#
# Now on startup number 787 --> GTX Medical
# Number of startups left: 59
#
# Now on startup number 788 --> Nomoko
# Number of startups left: 58
#
# Now on startup number 789 --> Arviem
# Number of startups left: 57
#
# Now on startup number 790 --> Tradeplus24
# Number of startups left: 56
#
# Now on startup number 791 --> Monday
# Number of startups left: 55
#
# Now on startup number 792 --> Xeltis
# Number of startups left: 54
#
# Now on startup number 793 --> ScanTrust
# Number of startups left: 53
#
# Now on startup number 794 --> Tangem
# Number of startups left: 52
#
# Now on startup number 795 --> TrekkSoft
# Number of startups left: 51
#
# Now on startup number 796 --> Thingstream
# Number of startups left: 50
#
# Now on startup number 797 --> CodeCheck
# Number of startups left: 49
#
# Now on startup number 798 --> Bloom Diagnostics
# Number of startups left: 48
#
# Now on startup number 799 --> Piavita
# Number of startups left: 47
#
# Now on startup number 800 --> Jahia
# Number of startups left: 46
#
# Now on startup number 801 --> Gmelius
# Number of startups left: 45
#
# Now on startup number 802 --> Lunaphore Technologies
# Number of startups left: 44
#
# Now on startup number 803 --> pCloud
# Number of startups left: 43
#
# Now on startup number 804 --> SENSIMED
# Number of startups left: 42
#
# Now on startup number 805 --> Mymeleon
# Number of startups left: 41
#
# Now on startup number 806 --> Colendi
# Number of startups left: 40
#
# Now on startup number 807 --> Datum
# Number of startups left: 39
#
# Now on startup number 808 --> hystrix medical
# Number of startups left: 38
#
# Now on startup number 809 --> Amal Therapeutics
# Number of startups left: 37
#
# Now on startup number 810 --> ImmuniWeb
# Number of startups left: 36
#
# Now on startup number 811 --> Advertima
# Number of startups left: 35
#
# Now on startup number 812 --> Nezasa
# Number of startups left: 34
#
# Now on startup number 813 --> Open Mineral
# Number of startups left: 33
#
# Now on startup number 814 --> MyCujoo
# Number of startups left: 32
#
# Now on startup number 815 --> Mitto
# Number of startups left: 31
#
# Now on startup number 816 --> Farmy
# Number of startups left: 30
#
# Now on startup number 817 --> RightMesh
# Number of startups left: 29
#
# Now on startup number 818 --> additiv
# Number of startups left: 28
#
# Now on startup number 819 --> Westhive Coworking Ecosystem
# Number of startups left: 27
#
# Now on startup number 820 --> KiWi
# Number of startups left: 26
#
# Now on startup number 821 --> MyKronoz
# Number of startups left: 25
#
# Now on startup number 822 --> Remoto
# Number of startups left: 24
#
# Now on startup number 823 --> qiibee
# Number of startups left: 23
#
# Now on startup number 824 --> Fotokite
# Number of startups left: 22
#
# Now on startup number 825 --> Amazentis
# Number of startups left: 21
#
# Now on startup number 826 --> TestingTime
# Number of startups left: 20
#
# Now on startup number 827 --> NovaDAX
# Number of startups left: 19
#
# Now on startup number 828 --> Kido Dynamics
# Number of startups left: 18
#
# Now on startup number 829 --> LEND
# Number of startups left: 17
#
# Now on startup number 830 --> Qumram
# Number of startups left: 16
#
# Now on startup number 831 --> Aximetria
# Number of startups left: 15
#
# Now on startup number 832 --> 9TLabs
# Number of startups left: 14
#
# Now on startup number 833 --> WECHEER
# Number of startups left: 13
#
# Now on startup number 834 --> PIQ
# Number of startups left: 12
#
# Now on startup number 835 --> Fashwell
# Number of startups left: 11
#
# Now on startup number 836 --> Sequana Medical
# Number of startups left: 10
#
# Now on startup number 837 --> WealthArc
# Number of startups left: 9
#
# Now on startup number 838 --> Ledgy
# Number of startups left: 8
#
# Now on startup number 839 --> WeCheer
# Number of startups left: 7
#
# Now on startup number 840 --> CUTISS
# Number of startups left: 6
#
# Now on startup number 841 --> SAGE Group
# Number of startups left: 5
#
# Now on startup number 842 --> Debiopharm Group
# Number of startups left: 4
#
# Now on startup number 843 --> Foodetective
# Number of startups left: 3
#
# Now on startup number 844 --> Mt Pelerin
# Number of startups left: 2
#
# Now on startup number 845 --> Pryv
# Number of startups left: 1
#
# Now on startup number 846 --> Legartis
# Number of startups left: 0

# %% [markdown]
# <p>
#     <b>
#     After scraping all the data, we are converting dictionaries with our data into pandas dataframes.
#     </b>
# </p>

# %%
cb = pd.DataFrame(d_)

# %%
cb.sort_values('Startup', inplace= True)

# %%
cb.head()
# Out:
#                     Startup       Size  CB rank Total funding  \
# 685                200crowd      11-50   39,694         €300K
# 663  24 Ore Business School  1001-5000  141,808           NaN
# 442              24sessions      11-50   14,516         $1.5M
# 445                   30MHz      11-50   17,051         €4.9M
# 175             360Learning    101-250    3,300        $42.6M
#
#     Last funding type  Investments  Acquisitions  Team members Founded date  \
# 685              Seed          NaN           NaN           7.0         2015
# 663               NaN          NaN           NaN           2.0  Nov 9, 1965
# 442          Series A          NaN           NaN           6.0  Oct 1, 2015
# 445          Series A          NaN           NaN           4.0         2014
# 175          Series B          NaN           NaN           6.0         2009
#
#     IPO status Operating status Company type
# 685    Private           Active   For Profit
# 663    Private           Active   For Profit
# 442    Private           Active   For Profit
# 445    Private           Active   For Profit
# 175    Private           Active   For Profit

# %%
ind = pd.DataFrame(industries)

# %%
ind.sort_values('Startup', inplace= True)

# %%
ind.head(7)
# Out:
#                   Startup            Industry
# 0                200crowd        Crowdfunding
# 1                200crowd  Financial Services
# 2                200crowd             FinTech
# 3                200crowd    Funding Platform
# 4  24 Ore Business School                News
# 5  24 Ore Business School          Publishing
# 6              24sessions                SaaS

# %% [markdown]
# <p>Now let's merge DataFrames <b><i>startups_table</i></b> and <b><i>cb</i></b>
# .</p>

# %%
startups_table.sort_values('Startup', inplace = True)

# %%
startups_table.head(1)
# Out:
#       Startup Country   City  \
# 688  200crowd   Italy  Milan
#
#                                            Description                   Url
# 688  200 Crowd is a Crowdfunding platform that conn...  https://200crowd.com

# %%
cb.head(1)
# Out:
#       Startup   Size CB rank Total funding Last funding type  Investments  \
# 685  200crowd  11-50  39,694         €300K              Seed          NaN
#
#      Acquisitions  Team members Founded date IPO status Operating status  \
# 685           NaN           7.0         2015    Private           Active
#
#     Company type
# 685   For Profit

# %% [markdown]
# <p style="color:black">
#     <i>
#         <b>1-st: </b>Sorted 2 DataFrames on Startup name.
#    <b>
#     2-nd:
#    </b>
#       Merged 2 dataframes on index.
#
# In 2nd case it left two 'Startup' columns from first and second df as 'Startup_x' and 'Startup_y', we are going to drop 'Startup_y' and rename the remaining one as 'Startup'.</i> </p>

# %%
df = pd.merge(cb, startups_table, left_index=True, right_index=True)

# %%
df.drop(columns = ['Startup_y'], inplace = True )

# %%
df.rename(columns = {'Startup_x': 'Startup'}, inplace = True)

# %%
df.head()
# Out:
#                     Startup       Size  CB rank Total funding  \
# 685                200crowd      11-50   39,694         €300K
# 663  24 Ore Business School  1001-5000  141,808           NaN
# 442              24sessions      11-50   14,516         $1.5M
# 445                   30MHz      11-50   17,051         €4.9M
# 175             360Learning    101-250    3,300        $42.6M
#
#     Last funding type  Investments  Acquisitions  Team members Founded date  \
# 685              Seed          NaN           NaN           7.0         2015
# 663               NaN          NaN           NaN           2.0  Nov 9, 1965
# 442          Series A          NaN           NaN           6.0  Oct 1, 2015
# 445          Series A          NaN           NaN           4.0         2014
# 175          Series B          NaN           NaN           6.0         2009
#
#     IPO status Operating status Company type      Country       City  \
# 685    Private           Active   For Profit        Italy      Milan
# 663    Private           Active   For Profit        Italy       Rome
# 442    Private           Active   For Profit  Netherlands  Rotterdam
# 445    Private           Active   For Profit  Netherlands  Amsterdam
# 175    Private           Active   For Profit       France      Paris
#
#                                            Description  \
# 685  nCore HR is a modern video ATS/Recruiting & Vi...
# 663  Enel is a multi-national power company special...
# 442  Helloprint is Europe's fastest growing online ...
# 445  Unless is a predictive personalization platfor...
# 175  JobTeaser is a European job board platform for...
#
#                                     Url
# 685             https://ncorehr.com/en/
# 663              https://enel.com/en-GB
# 442              https://helloprint.com
# 445                  https://unless.com
# 175  https://corporate.jobteaser.com/fr

# %% [markdown]
# <p>
#     <b>
#             We are done with our data.
#             <br>
#             <br>
#             Now we are going to store those Dataframes in PostgreSQL Database.
#     </b>
#
# </p>

# %% [markdown]
# <p style="color:DodgerBlue; font-size:23px;"><b> 3. Storing data in a database.</b></p>

# %% [markdown]
# <p>
#     To store our data in DB, we are going to use the <b>psycopg2</b> which is PostgreSQL database adapter for Python.
#     <br>
#     This will allow us to make database operations through python.
# </p>

# %%
import psycopg2

# %%
#connecting to DB
conn = psycopg2.connect("dbname=db user=user password=password")

# %%
#creating cursor to make DB operations
cur = conn.cursor()

# %% [markdown]
# <p>Creating table for the <b>main</b> DataFrame</p>

# %%
table_main = '''
CREATE TABLE main(
Startup VARCHAR PRIMARY KEY,
Size VARCHAR,
"CB rank" VARCHAR,
"Total funding" VARCHAR,
"Last funding type" VARCHAR,
"Investments" NUMERIC,
"Acquisitions" NUMERIC,
"Team members" NUMERIC,
"Founded date" VARCHAR,
"IPO status" VARCHAR(7),
"Operating status" CHAR(6),
"Company type" CHAR(10),
Country VARCHAR,
City VARCHAR,
Desctiption VARCHAR,
Url VARCHAR
);
''' 
#executing command in DB
cur.execute(table_main)

# %% [markdown]
# <p>Adding values of the <b>main</b> table</p>

# %%
values = ','.join(['%s' for c in df.columns])   #making placeholders for our data

# %%
values
# Out:
# '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s'

# %%
query = "INSERT INTO main VALUES ({});".format(values)

# %%
for v in df.values: #inserting values one by one
    cur.execute(query, v)

# %%
conn.commit() #saving changes to DB

# %% [markdown]
# <p>Let's see our data in DB</p>

# %%
cur.execute('SELECT * FROM main;')

# %%
for row in cur.fetchmany(3): print(row, '\n')
# Out:
# ('9TLabs', '11-50', '10,788', '$5.5M', 'Seed', Decimal('NaN'), Decimal('NaN'), Decimal('3.0'), '2018', 'Private', 'Active', 'For Profit', 'Switzerland', 'Zürich', '9T Labs advances lightweight design by simplifying the use of high-performance materials.', 'https://9tlabs.com/')
#
# ('ABA English', '51-100', '8,814', '$15.4M', 'Venture - Series Unknown', Decimal('NaN'), Decimal('NaN'), Decimal('5.0'), '2007', 'Private', 'Active', 'For Profit', 'Spain', 'Barcelona', 'ABA English offers a unique teaching methodology and uses its own proprietary technology.', 'https://abaenglish.com/en/')
#
# ('ABB', '10001+', '1,418', '$2.7M', 'Grant', Decimal('5.0'), Decimal('31.0'), Decimal('63.0'), 'Jan 5, 1988', 'Private', 'Active', 'For Profit', 'Switzerland', 'Zürich', 'ABB provides power and automation technologies for smart grids, robotics, electric cars, renewable energy and motors.', 'https://abb.com')

# %% [markdown]
# <p>
#    In <b>DF</b> DataFrame - <b><i>Startup</i></b> is a primary key.
#
#
#    In <b>IND</b> DataFrame - <b><i>Startup</i></b> is a foreign key and references <b><i>Startup</i></b> in <b>DF DataFrame</b>.
#
# Primary keys of <b>IND</b> DataFrame are <i><b>Startup</b></i> and <i><b>Industry</b></i></p>

# %%
table_ind = '''
CREATE TABLE industry(
Startup VARCHAR,
Industry VARCHAR,
PRIMARY KEY(Startup, Industry),
FOREIGN KEY(Startup)
    REFERENCES main(Startup)
    ON DELETE CASCADE
);
'''

# %%
cur.execute(table_ind) #execute query

# %% [markdown]
# <p><i>Adding values of the <b>industry</b> table</i></p>

# %%
values_ = ','.join(['%s' for c in ind.columns])

# %%
values_
# Out:
# '%s,%s'

# %%
query_ = 'INSERT INTO industry VALUES ({});'.format(values_)

# %%
for v in ind.values:
    cur.execute(query_, v)

# %%
conn.commit() #saving changes to db

# %%
cur.execute('SELECT * FROM industry')

# %%
for row in cur.fetchmany(7): print(row, '\n')
# Out:
# ('200crowd', 'Crowdfunding')
#
# ('200crowd', 'Financial Services')
#
# ('200crowd', 'FinTech')
#
# ('200crowd', 'Funding Platform')
#
# ('24 Ore Business School', 'News')
#
# ('24 Ore Business School', 'Publishing')
#
# ('24sessions', 'SaaS')

# %%
cur.close() 
conn.close() #closing connection with db

# %% [markdown]
# <p style="color:dodgerblue; font-size:25px"><b>Now we have finished with the first part of getting the data and storing it in a database. <br> <br>
# In the second part to we are going to clean the data and perform EDA.<b> </p>
